# %%
! pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 58.2 MB/s eta 0:00:00:00:010:01
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 13.4 MB/s eta 0:00:0000:01
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 9.7 MB/s eta 0:00:00:00:01
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.2 pytz-2024.1 tzdata-2024.1
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
## Parallel processing & retries with slight changes in  prompt
import os
import io
import json
import pandas as pd
from dotenv import load_dotenv
import PyPDF2
from azure.storage.blob import ContainerClient
from openai import AzureOpenAI
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

# Load environment variables
load_dotenv()

# Set up Azure Blob Storage connection
connection_string = os.getenv("AZURE_STORAGE_CONNECTION_STRING")
container_name = "earningcalltranscriptscontainer"  # Replace with your container name
container_client = ContainerClient.from_connection_string(
    conn_str=connection_string,
    container_name=container_name
)

# Function to extract text from a PDF file stream
def extract_text_from_pdf(file_stream):
    text = ""
    try:
        pdf_reader = PyPDF2.PdfReader(file_stream)
        for page in pdf_reader.pages:
            page_text = page.extract_text()
            if page_text:
                text += page_text
    except Exception as e:
        print(f"Error extracting text from PDF: {e}")
    return text

# Function to truncate text to fit within the token limit
def truncate_text(input_text, max_tokens):
    tokens = input_text.split()  # Naive tokenization by splitting on spaces
    if len(tokens) > max_tokens:
        truncated_text = ' '.join(tokens[:max_tokens])
        return truncated_text
    return input_text

# Function to interact with Azure OpenAI and generate JSON output
def get_json(file_stream):
    # Initialize Azure OpenAI client
    client = AzureOpenAI(
        azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
        api_key=os.getenv("AZURE_OPENAI_API_KEY"),
        api_version="2024-02-01"
    )

    # Extract text from PDF
    input_context = extract_text_from_pdf(file_stream)

    # Truncate the input context to avoid exceeding token limit
    max_input_tokens = 12000  # Set max input tokens (adjust as needed)
    input_context = truncate_text(input_context, max_input_tokens)

    # System and user instructions for the OpenAI model
    instructions = """
     As a Financial Analyst, you will leverage your expertise to generate tailored Financial Analysis 
     Reports that cater to the specific requirements of clients. 
    Key Objectives:

    Extract and Present: Provide detailed figures for each metric listed above, ensuring accurate and up-to-date data.
    Categorize Clearly: Organize the metrics under their respective categories as outlined.
    Ensure Completeness: Verify that all relevant metrics are included and presented with sufficient context for accurate interpretation.
    Highlight Capital Expenditure: Ensure that capital expenditure-related metrics are prominently detailed and clearly separated from other categories.
    """
    
    user_content = f"""
    To extract and organize financial metrics from the report, including those related to capital expenditure, profitability, liquidity, solvency, cash flow, and other key indicators. The metrics should be categorized and detailed according to their relevance to different aspects of financial analysis. 

    Operating Activities "Change in Working Capital",
            "Net Cash from Operating Activities"
    Investing Activities has "Acquisition of Fixed Assets & Intangibles",
            "Net Cash from Investing Activities"
    Financing Activities includes "Dividends Paid",
            "Cash from (Repayment of) Debt",
            "Net Cash from Financing Activities",
    Net Change includes  Net Change in Cash
    Metadata includes "Report Date", "Publish Date", "Source"
    Profitability Metrics like "EBITDA",
            "Gross Profit Margin",
            "Operating Margin",
            "Net Profit Margin",
            "Return on Equity",
            "Return on Assets",
            "Return On Invested Capital",
    Liquidity Metrics include Current Ratio
    Solvency Metrics like  "Total Debt", "Liabilities to Equity Ratio", "Debt Ratio",
    Cash Flow Metrics like "Free Cash Flow", "Free Cash Flow to Net Income", "Cash Return On Invested Capital",
    Other Important Metrics like "Piotroski F-Score", "Net Debt / EBITDA", "Dividend Payout Ratio
    Capital Expenditure 
    ```Document
    {input_context}
    ```
    """

    # JSON output structure request
    final_content = """
    Please provide the company name, year and quarter, capital expenditure value in billions of US dollars in JSON format.
    Use the following JSON structure:
    ```json
    {{
        "company": "",
        "year": "",
        "quarter": "",
        "capex": ""    
    }}
    ```
    Note: Only JSON Data is required, no other text is required.
    """

    # Steps to find the capital expenditure value
    how_content = """
    Please provide the steps how you found or calculated the capital expenditure value.
    """

    messages = [
        {"role": "system", "content": instructions},
        {"role": "user", "content": user_content}
    ]

    try:
        # Initial completion request
        response = client.chat.completions.create(
            model=os.getenv("DEPLOYMENT_NAME"),
            messages=messages,
        )
        response_content = response.choices[0].message.content
        messages.append({"role": "assistant", "content": response_content})
        messages.append({"role": "user", "content": final_content})
    except Exception as e:
        print(f"Error during OpenAI response generation: {e}")
        return None, None

    try:
        # Requesting JSON formatted data
        response_json = client.chat.completions.create(
            model=os.getenv("DEPLOYMENT_NAME"),
            messages=messages,
        )
        messages.append({"role": "assistant", "content": response_json.choices[0].message.content})
        messages.append({"role": "user", "content": how_content})

        # Requesting explanation of how the value was found
        how_response = client.chat.completions.create(
            model=os.getenv("DEPLOYMENT_NAME"),
            messages=messages
        )
    except Exception as e:
        print(f"Error during JSON extraction or explanation generation: {e}")
        return None, None

    return response_json.choices[0].message.content, how_response.choices[0].message.content

# Function to process a single blob with retry logic
def process_blob(blob, retries=3):
    attempt = 0
    while attempt < retries:
        try:
            stream = io.BytesIO()
            container_client.download_blob(blob).readinto(stream)
            op, how = get_json(stream)
            if op and how:
                op = json.loads(op[op.index("{"):len(op)-op[::-1].index("}")])
                if op.get("capex"):  # Check if capex is not empty
                    return op, how
                else:
                    print(f"Capex is empty. Retrying for blob {blob.name}...")
            attempt += 1
            time.sleep(5)  # Wait before retrying
        except Exception as e:
            print(f"Error processing blob {blob.name}: {e}")
            return None, None
    print(f"Max retries reached for blob {blob.name}.")
    return None, None

# Main function to process blobs in parallel
def main():
    final_json = []
    blob_list = list(container_client.list_blobs())[:40]  # Limit to the first 40 blobs

    # Using ThreadPoolExecutor for parallel processing
    with ThreadPoolExecutor(max_workers=5) as executor:
        future_to_blob = {executor.submit(process_blob, blob): blob for blob in blob_list}
        # Iterate over completed futures
        for future in as_completed(future_to_blob):
            blob = future_to_blob[future]
            try:
                result = future.result()
                if result:
                    op, how = result
                    if op:  # Ensure op is not None
                        print(op, "\n\n", how)
                        final_json.append(op)
            except Exception as e:
                print(f"Error processing result for blob {blob.name}: {e}")

    # Ensure final_json contains valid data
    final_json = [item for item in final_json if isinstance(item, dict)]
    # Optional: Save final JSON to a file
    output_file = "financial_analysis_results_1201.json"
    with open(output_file, "w") as outfile:
        json.dump(final_json, outfile, indent=4)

    # Convert final_json to DataFrame and save to CSV
    if final_json:  # Check if final_json is not empty
        df = pd.DataFrame(final_json)
        output_file = "financial_analysis_results10.csv"
        df.to_csv(output_file, index=False)
        print(f"Processing completed. Results saved to {output_file}.")
    else:
        print("No valid data to save to CSV.")

if __name__ == "__main__":
    main()
# Out:
# {'company': 'Alphabet Inc.', 'year': '2021', 'quarter': 'Q2', 'capex': '5.496'}
#
#  1. **Identify Relevant Section**: Review the financial report and locate the section dedicated to "Investing Activities."
#
# 2. **Locate Capital Expenditure**: Look for terms like "Purchases of Property and Equipment" or "Capital Expenditures," which are indicators of capital spending.
#
# 3. **Extract Figures**: For Q2 2021, the report listed "Purchases of Property and Equipment" as $5,496 million.
#
# 4. **Convert to Billions**: Convert the figure from millions to billions by dividing by 1,000:
#    \[
#    \text{Capex in billions} = \frac{5,496}{1,000} = 5.496
#    \]
#
# 5. **Summarize**: Confirm the value matches the format required (in billions) and note it down in the specified JSON format.
# {'company': 'Alphabet Inc.', 'year': '2021', 'quarter': 'Q4', 'capex': '6.383'}
#
#  To find or calculate the capital expenditure (CapEx) value for Alphabet Inc. for Q4 2021, the following steps were taken:
#
# 1. **Review Financial Statements**:
#    - I analyzed the provided financial report, specifically the Consolidated Statements of Cash Flows section.
#
# 2. **Locate Investing Activities**:
#    - Within the Cash Flow Statement, I focused on the "Investing activities" section, where capital expenditures are typically recorded.
#
# 3. **Identify Purchases of Property and Equipment**:
#    - I found the line item labeled "Purchases of property and equipment," which indicates the capital expenditure for fixed assets.
#
# 4. **Extract the Value**:
#    - For Q4 2021, the reported value for "Purchases of property and equipment" was $(6,383) million.
#
# 5. **Convert to Billions**:
#    - I converted the value from millions to billions by dividing by 1,000.
#    - Thus, $(6,383 million) = $6.383 billion.
#
# This led to the conclusion that the capital expenditure for Alphabet Inc. in Q4 2021 was $6.383 billion.
# {'company': 'Alphabet Inc.', 'year': '2022', 'quarter': 'Q1', 'capex': '9.786'}
#
#  To find or calculate the capital expenditure (CapEx) value for Alphabet Inc. in Q1 2022, follow these steps:
#
# 1. **Identify Relevant Sections**: Review the financial statements, particularly the Consolidated Statements of Cash Flows, where capital expenditures are typically listed under investing activities.
#
# 2. **Locate Capital Expenditure Data**: In the provided document, find the section that specifies “Purchases of property and equipment.” This is a common line item representing capital expenditures.
#
# 3. **Extract the Value**: From the Consolidated Statements of Cash Flows, note the value listed for Q1 2022:
#    - Q1 2022: **$(9,786) million**
#
# 4. **Convert to Billions**: Since the inquiry requires the value in billions of USD, convert the value from millions to billions:
#    - **$9,786 million** = **$9.786 billion**
#
# 5. **Compile the Data**: Organize the extracted information into the required format, ensuring to specify the company name, year, quarter, and the CapEx value in billions.
#
# By following these steps, the CapEx value was determined accurately from the available financial data.
# {'company': 'Alphabet Inc.', 'year': '2021', 'quarter': 'Q3', 'capex': '6.82'}
#
#  To extract and calculate the capital expenditure (capex) value for Alphabet Inc. in Q3 2021, the following steps were followed:
#
# 1. **Locate Financial Statement**:
#    - Review the provided financial report of Alphabet Inc. for Q3 2021.
#
# 2. **Identify Relevant Sections**:
#    - Focus on the "Consolidated Statements of Cash Flows" section, as it typically includes cash flows from operating, investing, and financing activities.
#
# 3. **Find Capital Expenditure**:
#    - In the "Investing Activities" section, capital expenditures are commonly denoted under phrases like "Purchases of Property and Equipment." In this case, it was explicitly listed.
#
# 4. **Extract the Value**:
#    - From the cash flows statement, the entry for **Purchases of Property and Equipment** was noted:
#      - Q3 2021: **$(6,819) million**.
#
# 5. **Convert to Billions**:
#    - Convert the value from millions to billions for clarity:
#      - \( 6,819 \, \text{million} = \frac{6,819}{1,000} = 6.819 \, \text{billion} \).
#
# 6. **Format the Result**:
#    - Round the value as needed based on context (usually to two decimal places), resulting in **6.82 billion**.
#
# These steps led to the final capital expenditure value for Alphabet Inc. in Q3 2021.
# {'company': 'Alphabet Inc.', 'year': '2021', 'quarter': 'Q1', 'capex': '5.942'}
#
#  To extract the capital expenditure value, the following steps were taken:
#
# 1. **Locate Financial Statements**: In the provided document, find the section titled "CONSOLIDATED STATEMENTS OF CASH FLOWS," which typically contains investing activities including capital expenditures.
#
# 2. **Identify Capital Expenditure Line Item**: Look for a line item that mentions purchases of property and equipment or similar terms. In this case, it was listed as "Purchases of Property and Equipment."
#
# 3. **Extract Value**: Read the value associated with that line item for the relevant quarter (Q1 2021). The value was found to be **$(5,942 million)**.
#
# 4. **Convert to Billions**: Since the requested format is in billions of US dollars, convert the figure from millions to billions by dividing by 1,000.
#    - Calculation: \( \frac{5,942}{1,000} = 5.942 \) billion USD.
#
# This resulted in the final figure of **5.942 billion USD** for capital expenditure in Q1 2021 for Alphabet Inc.
# {'company': 'Alphabet Inc.', 'year': '2022', 'quarter': 'Q4', 'capex': '7.6'}
#
#  Here are the steps to find or calculate the capital expenditure (CapEx) value for Alphabet Inc. based on the provided financial document:
#
# 1. **Identify the Relevant Section:**
#    - Locate the section of the document that discusses investing activities. This section typically contains information on capital expenditures.
#
# 2. **Locate the CapEx Figure:**
#    - Within the investing activities section, find the line item labeled "Purchases of property and equipment," which represents the capital expenditures for the company.
#
# 3. **Extract the Value:**
#    - Read the value associated with this line item for the desired quarter. In this case, for Q4 2022, the document indicates:
#      - Purchases of property and equipment: $(7,595) million.
#
# 4. **Convert to Billions:**
#    - Convert the value from millions to billions for easier interpretation:
#    - \( 7,595 \text{ million} \div 1,000 = 7.595 \text{ billion} \).
#    - This rounds to approximately 7.6 billion USD.
#
# 5. **Format the Result:**
#    - Format the extracted value into the requested JSON structure as specified.
#
# By following these steps, you accurately identify and calculate the capital expenditure value for the specified quarter.
# {'company': 'Alphabet Inc.', 'year': '2022', 'quarter': 'Q3', 'capex': '7.276'}
#
#  1. **Identify the Relevant Section**: In the financial report, locate the section titled "Consolidated Statements of Cash Flows," which details the cash flows from operating, investing, and financing activities.
#
# 2. **Locate Capital Expenditure Line Items**: Within the investing activities portion of the cash flows, look for line items that mention purchases related to property and equipment or intangible assets.
#
# 3. **Extract Capital Expenditure (CapEx) Data**: For Q3 2022, the relevant line item found was "Purchases of property and equipment," which stated a value of $7,276 million.
#
# 4. **Convert to Billions**: Convert the extracted capital expenditure value from millions to billions by dividing by 1,000:
#    - \( 7,276 \, \text{million} \div 1,000 = 7.276 \, \text{billion} \)
#
# 5. **Format Results**: Organize this data in a structured format (in this case, JSON) for clarity and presentation.
#
# These steps ensured accurate extraction and calculation of capital expenditure from the provided financial report.
# Error during JSON extraction or explanation generation: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-02-01 have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error during JSON extraction or explanation generation: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-02-01 have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# {'company': 'Alphabet Inc.', 'year': '2023', 'quarter': 'Q3', 'capex': '8.055'}
#
#  To determine the capital expenditure (capex) value for Alphabet Inc. for Q3 2023, the following steps were taken:
#
# 1. **Locate Financial Statements**: Access the official financial report from Alphabet Inc. for Q3 2023.
#
# 2. **Identify Relevant Section**: Within the financial statements, locate the "Consolidated Statements of Cash Flows," which details cash flows from operating, investing, and financing activities.
#
# 3. **Find Capital Expenditure**: Look for the line item titled "Purchases of Property and Equipment," which typically represents capital expenditures.
#
# 4. **Extract Capex Value**: Note the value listed for "Purchases of Property and Equipment" for the quarter ended September 30, 2023.
#
# 5. **Convert to Billions**: The raw value is presented in millions; divide the figure by 1,000 to convert it to billions.
#
# 6. **Compile Final Data**: Format the extracted value in the required JSON structure, ensuring accuracy in the company name, year, and quarter.
#
# By following these steps, the capital expenditure for Alphabet Inc. in Q3 2023 was identified as **$8.055 billion**.
# {'company': 'Alphabet Inc.', 'year': '2023', 'quarter': 'Q2', 'capex': '6.888'}
#
#  To find the capital expenditure (CapEx) value for Alphabet Inc. for Q2 2023, I followed these steps:
#
# 1. **Review Financial Statements:**
#    - Accessed the consolidated statements of cash flows in the provided financial document.
#
# 2. **Identify CapEx Item:**
#    - Located the line item directly related to capital expenditures, which is typically labeled as "Purchases of Property and Equipment."
#
# 3. **Extract Value:**
#    - Read the reported value under the Q2 2023 column for "Purchases of Property and Equipment," which was listed as **$6,888 million**.
#
# 4. **Convert to Billions:**
#    - Converted the value from millions to billions by dividing by 1,000:
#      \[
#      6,888 \text{ million} = 6.888 \text{ billion}
#      \]
#
# By performing these steps, I confirmed that the capital expenditure value for Q2 2023 was **6.888 billion US dollars**.
# Error during JSON extraction or explanation generation: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-02-01 have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# {'company': 'Alphabet Inc.', 'year': '2024', 'quarter': 'Q1', 'capex': '12.012'}
#
#  Here are the steps to find or calculate the capital expenditure (CapEx) value:
#
# 1. **Locate the Financial Statements**:
#    - Review the Consolidated Statements of Cash Flows section in the financial report.
#
# 2. **Identify the Investing Activities**:
#    - Look for the "Investing Activities" subsection within the cash flow statement.
#
# 3. **Find CapEx Line Item**:
#    - In the investing activities, locate the line item titled "Purchases of property and equipment." This line item typically represents capital expenditures.
#
# 4. **Record the Value**:
#    - Note the value listed under "Purchases of property and equipment" for the relevant quarter. In this case, for Q1 2024, it was **$12,012 million**.
#
# 5. **Convert to Billions**:
#    - Since the request was for CapEx in billions, convert the value from millions to billions by dividing by 1,000. Therefore, **$12,012 million / 1,000 = $12.012 billion**.
#
# 6. **Format as Needed**:
#    - Prepare the final value in the specified JSON format.
# {'company': 'Alphabet Inc.', 'year': '2023', 'quarter': 'Q4', 'capex': '11.019'}
#
#  To find or calculate the capital expenditure (CapEx) value, follow these steps:
#
# 1. **Locate the Relevant Section**:
#    - Review the financial statements provided in the earnings report, particularly the cash flow statement or additional disclosures regarding capital expenditures.
#
# 2. **Identify CapEx Items**:
#    - Look for phrases such as "Purchases of property and equipment" or "Acquisitions of Fixed Assets & Intangibles."
#
# 3. **Extract the Value**:
#    - For Q4 2023, the report states:
#      - "Purchases of property and equipment (CapEx): $(11,019) million."
#
# 4. **Convert to Billions**:
#    - Since the extracted figure is in millions, divide it by 1,000 to convert to billions:
#      - \( 11,019 \div 1,000 = 11.019 \) billion USD.
#
# 5. **Compile the Data**:
#    - Format the extracted value into the desired JSON structure as specified.
#
# Following these steps ensures an accurate identification and calculation of the capital expenditure for the specified quarter and year.
# {'company': 'Alphabet Inc.', 'year': '2022', 'quarter': 'Q2', 'capex': '7.89'}
#
#  To determine the capital expenditure (capex) value for Alphabet Inc. in Q2 2022, the following steps were taken:
#
# 1. **Identify Relevant Sections in the Financial Report:**
#    - The capital expenditure data is generally detailed within the "Cash Flows from Investing Activities" section.
#
# 2. **Extract Capital Expenditure Figures:**
#    - Look for specific lines related to capital expenditures in the cash flow statement. In the provided document, the relevant figures are:
#      - Purchases of Property and Equipment: **$6,828 million**
#      - Acquisitions, net of cash acquired, and purchases of intangible assets: **$1,063 million**
#
# 3. **Calculate Total Capital Expenditures:**
#    - Add the values extracted from the report:
#      - Total Capital Expenditures (Capex) = Purchases of Property and Equipment + Acquisitions
#      - Total Capex = $6,828 million + $1,063 million = $7,891 million
#
# 4. **Convert to Billions:**
#    - Convert the total capex value from millions to billions:
#      - $7,891 million = $7.891 billion
#
# 5. **Format the Result:**
#    - Format the calculated value into the requested JSON structure for clarity and precision.
#
# By following these steps, the calculated capital expenditure value for Alphabet Inc. for Q2 2022 was determined to be $7.891 billion.
# {'company': 'Amazon.com, Inc.', 'year': '2020', 'quarter': 'Q1', 'capex': '6.8'}
#
#  To find or calculate the capital expenditure (capex) value for Amazon.com, Inc. for Q1 2020, I followed these steps:
#
# 1. **Identify Relevant Sections**: I reviewed the provided financial document, particularly focusing on sections that mention capital expenditures or related metrics.
#
# 2. **Find Specific Metric**: The key metric for capital expenditure is typically the "Purchases of Property and Equipment." In the financial statement, I located the following data:
#    - **Purchases of Property and Equipment (Q1 2020):** $(6,795 million)
#
# 3. **Convert to Billions**: Since financial figures are often presented in millions and the required format is in billions, I converted this value:
#    - $6,795 million = $6.795 billion
#
# 4. **Format the Value**: I formatted the figure to fit the required JSON specification while ensuring it aligns with the requested details (company name, year, quarter).
#
# 5. **Compile Information**: Finally, I structured the complete information into the prescribed JSON format.
#
# This process led to the final capital expenditure value of $6.8 billion for the first quarter of 2020 for Amazon.com, Inc. (rounded as necessary for presentation).
# {'company': 'Alphabet Inc.', 'year': '2024', 'quarter': 'Q2', 'capex': '13.2'}
#
#  To find or calculate the capital expenditure (capex) value for Alphabet Inc. for Q2 2024, follow these steps:
#
# 1. **Identify the Relevant Section:** Locate the section of the financial report that discusses cash flows, specifically the "Consolidated Statements of Cash Flows."
#
# 2. **Extract Cash Flow Details:**
#    - Find the line item labeled "Purchases of property and equipment.” This line item typically represents capital expenditures.
#
# 3. **Read the Value:**
#    - From the Q2 2024 section of the cash flow statement, the value listed for "Purchases of property and equipment" was $13,186 million.
#
# 4. **Convert to Billions:**
#    - Since financial reports often present figures in millions, convert the capex value to billions for the required format:
#      - $13,186 million ÷ 1,000 = $13.186 billion.
#
# 5. **Round as Necessary:**
#    - In the context provided, it was appropriate to round to one decimal place, resulting in $13.2 billion for the capex value.
#
# By following these steps, the capex value of $13.2 billion was determined for Alphabet Inc. in Q2 2024.

# %%
## Rearranged input capex with quarter_year with company name 
import pandas as pd

# Read the original CSV file
input_file = "financial_analysis_results10.csv"
df = pd.read_csv(input_file)

# Convert 'quarter' and 'year' columns into a single 'Quarter-Year' column with an underscore
df['Quarter-Year'] = df['quarter'] + "_" + df['year'].astype(str)

# Pivot the DataFrame
pivot_df = df.pivot_table(index='company', columns='Quarter-Year', values='capex', aggfunc='first')

# Reset the index to make 'company' a column instead of an index
pivot_df.reset_index(inplace=True)

# Define a function to sort columns in the desired order
def sort_columns(df):
    # Extract the current columns
    columns = df.columns.tolist()
    
    # Extract the company column and the Quarter-Year columns
    company_col = columns[0]
    quarter_cols = columns[1:]
    
    # Generate sorted columns list: Start with the most recent quarters
    sorted_quarters = sorted(quarter_cols, key=lambda x: (x.split('_')[1], x.split('_')[0]), reverse=True)
    
    # Combine sorted columns with the company column
    sorted_columns = [company_col] + sorted_quarters
    return sorted_columns

# Reorder the columns
sorted_columns = sort_columns(pivot_df)
pivot_df = pivot_df[sorted_columns]

# Save the rearranged DataFrame to a new CSV file
output_file = "rearranged_financial_analysis_results1.csv"
pivot_df.to_csv(output_file, index=False)

print(f"Rearranged data saved to {output_file}.")
# Out:
# Rearranged data saved to rearranged_financial_analysis_results1.csv.

# %%
import pandas as pd
import numpy as np

# Load the existing financial data
input_file = 'rearranged_financial_analysis_results1.csv'
df = pd.read_csv(input_file)

# Define quarters and years in the desired order
quarters = ['Q4', 'Q3', 'Q2', 'Q1']
years = list(range(2024, 2013, -1))  # From 2024 to 2014
quarters_years = [f"{q}_{y}" for y in years for q in quarters]

# Create the template DataFrame with these columns
template_df = pd.DataFrame(columns=['company'] + quarters_years)

# Standardize company names
df['company'] = df['company'].replace({
    'Amazon': 'Amazon.com',
    'Amazon.com, Inc.': 'Amazon.com',
    'Alphabet Inc':'Alphabet Inc.'
})

# Create a new DataFrame to hold aggregated data
aggregated_data = df.groupby('company').sum(numeric_only=True).reset_index()

# Initialize the template DataFrame
template_data = {'company': list(aggregated_data['company'])}
for quarter in quarters_years:
    template_data[quarter] = [np.nan] * len(template_data['company'])

template_df = pd.DataFrame(template_data)

# Merge the aggregated data with the template DataFrame
# First, ensure the column names in aggregated_data match the template_df
matching_columns = [col for col in aggregated_data.columns if col in template_df.columns]
merged_df = pd.merge(template_df, aggregated_data, on='company', how='left', suffixes=('', '_agg'))

# Map the values from aggregated_data to template_df
for column in quarters_years:
    if column in matching_columns:
        merged_df[column] = merged_df[f"{column}_agg"]

# Drop the extra columns used during the merge
final_df = merged_df.drop(columns=[col for col in merged_df.columns if col.endswith('_agg')])

# Fill missing values with NaN
for column in final_df.columns[1:]:
    final_df[column] = final_df[column].fillna(np.nan)
# Replace 0 with NaN
final_df.replace(0, np.nan, inplace=True)
# Save the result to a new CSV file if needed
final_df.to_csv('combined_financial_analysis_results.csv', index=False)

#print(final_df)

# %%
# compare the Capex with previous quarter value and decide either increase, decrease or data unavailable, unchanged

# Read the CSV file
input_file = "combined_financial_analysis_results.csv"
df = pd.read_csv(input_file)

# Define a function to compare capex values between consecutive columns
def compare_columns(row):
    comparisons = []
    for i in range(1, len(row) - 1):  # Skip the 'company' column
        current_value = row[i]
        next_value = row[i + 1]
        
        if pd.isna(current_value) or pd.isna(next_value):
            comparisons.append("Data not available")
        else:
            try:
                current_value = float(current_value)
                next_value = float(next_value)
                if next_value < current_value:
                    comparisons.append("increase")
                elif next_value > current_value:
                    comparisons.append("decrease")
                else:
                    comparisons.append("unchanged")
            except ValueError:
                comparisons.append("Data not available")
    
    return comparisons

# Apply the comparison function to each row
comparison_results = df.apply(lambda row: compare_columns(row), axis=1)

# Generate column names for comparison results
quarter_columns = df.columns[1:]  # Exclude 'company'
comparison_columns = [f"Compare_{quarter_columns[i]}_{quarter_columns[i+1]}" for i in range(len(quarter_columns) - 1)]

# Create DataFrame for comparison results
comparison_df = pd.DataFrame(comparison_results.tolist(), columns=comparison_columns)

# Combine the company column with the comparison results
final_comparison_df = pd.concat([df[['company']], comparison_df], axis=1)

# Save the comparison results to a new CSV file
output_file = "capex_comparison_results.csv"
final_comparison_df.to_csv(output_file, index=False)

print(f"Capex comparison results saved to {output_file}.")
# Out:
# Capex comparison results saved to capex_comparison_results.csv.
# /tmp/ipykernel_75725/439761825.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_value = row[i]
# /tmp/ipykernel_75725/439761825.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   next_value = row[i + 1]
